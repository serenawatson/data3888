# %%
import pandas as pd

import scipy.cluster.hierarchy as shc
from sklearn.cluster import KMeans

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

from scipy.spatial.distance import squareform, pdist

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("data/data.txt")
df = df.drop(columns='Unnamed: 0')
df
# Out:
#       iso_code  location continent        date  new_cases_per_million  \
# 0          ALB   Albania    Europe  2020-02-25                    NaN
# 1          ALB   Albania    Europe  2020-02-26                    NaN
# 2          ALB   Albania    Europe  2020-02-27                    NaN
# 3          ALB   Albania    Europe  2020-02-28                    NaN
# 4          ALB   Albania    Europe  2020-02-29                    NaN
# ...        ...       ...       ...         ...                    ...
# 88602      ZWE  Zimbabwe    Africa  2022-03-22                  0.000
# 88603      ZWE  Zimbabwe    Africa  2022-03-23                 18.089
# 88604      ZWE  Zimbabwe    Africa  2022-03-24                 15.637
# 88605      ZWE  Zimbabwe    Africa  2022-03-25                 29.883
# 88606      ZWE  Zimbabwe    Africa  2022-03-26                    NaN
#
#        new_cases_smoothed_per_million  stringency_index  positive_rate  \
# 0                                 NaN              8.33            NaN
# 1                                 NaN              8.33            NaN
# 2                                 NaN              8.33            NaN
# 3                                 NaN              8.33            NaN
# 4                                 NaN              8.33            NaN
# ...                               ...               ...            ...
# 88602                          16.811               NaN         0.0841
# 88603                          12.381               NaN         0.0648
# 88604                          14.615               NaN         0.0802
# 88605                          15.457               NaN            NaN
# 88606                             NaN               NaN            NaN
#
#        human_development_index  cost_living_index  tourist_service_index  \
# 0                        0.795              35.50                   4.01
# 1                        0.795              35.50                   4.01
# 2                        0.795              35.50                   4.01
# 3                        0.795              35.50                   4.01
# 4                        0.795              35.50                   4.01
# ...                        ...                ...                    ...
# 88602                    0.571              45.68                   2.95
# 88603                    0.571              45.68                   2.95
# 88604                    0.571              45.68                   2.95
# 88605                    0.571              45.68                   2.95
# 88606                    0.571              45.68                   2.95
#
#        international_travel_controls
# 0                                1.0
# 1                                1.0
# 2                                1.0
# 3                                1.0
# 4                                1.0
# ...                              ...
# 88602                            NaN
# 88603                            NaN
# 88604                            NaN
# 88605                            NaN
# 88606                            NaN
#
# [88607 rows x 12 columns]

# %%
medians = df.groupby(["location"]).median()
medians
# Out:
#            new_cases_per_million  new_cases_smoothed_per_million  \
# location
# Albania                  58.3030                         86.7700
# Algeria                   5.1100                          5.2990
# Argentina               153.4455                        151.1790
# Armenia                 109.6650                        119.0265
# Australia                 1.2800                          1.0750
# ...                          ...                             ...
# Venezuela                19.0560                         23.0870
# Vietnam                   0.1220                          0.1130
# Yemen                     0.1970                          0.2340
# Zambia                    5.6020                          6.6290
# Zimbabwe                  3.9760                          5.7840
#
#            stringency_index  positive_rate  human_development_index  \
# location
# Albania               56.48         0.1670                    0.795
# Algeria               69.44            NaN                    0.748
# Argentina             77.31         0.1830                    0.845
# Armenia                 NaN         0.1185                    0.776
# Australia             65.28         0.0009                    0.944
# ...                     ...            ...                      ...
# Venezuela             84.26            NaN                    0.711
# Vietnam               67.13         0.0719                    0.704
# Yemen                 27.78            NaN                    0.470
# Zambia                43.52         0.0395                    0.584
# Zimbabwe              67.59         0.0514                    0.571
#
#            cost_living_index  tourist_service_index  \
# location
# Albania                35.50                   4.01
# Algeria                26.87                   1.84
# Argentina              34.69                   4.53
# Armenia                33.89                   4.33
# Australia              77.75                   6.06
# ...                      ...                    ...
# Venezuela              43.20                   2.96
# Vietnam                37.48                   2.85
# Yemen                  53.14                   1.87
# Zambia                 33.04                   2.52
# Zimbabwe               45.68                   2.95
#
#            international_travel_controls
# location
# Albania                              2.0
# Algeria                              4.0
# Argentina                            3.0
# Armenia                              NaN
# Australia                            4.0
# ...                                  ...
# Venezuela                            4.0
# Vietnam                              4.0
# Yemen                                3.0
# Zambia                               2.0
# Zimbabwe                             2.0
#
# [116 rows x 8 columns]

# %%
medians = medians.fillna(df.median())
medians = medians.drop(columns = ["international_travel_controls"])
medians = medians.drop(columns = ["new_cases_per_million", "human_development_index"])
tourist = medians.drop(columns = ["positive_rate", "cost_living_index", "stringency_index"])

# %%
tourist
# Out:
#            new_cases_smoothed_per_million  tourist_service_index
# location
# Albania                           86.7700                   4.01
# Algeria                            5.2990                   1.84
# Argentina                        151.1790                   4.53
# Armenia                          119.0265                   4.33
# Australia                          1.0750                   6.06
# ...                                   ...                    ...
# Venezuela                         23.0870                   2.96
# Vietnam                            0.1130                   2.85
# Yemen                              0.2340                   1.87
# Zambia                             6.6290                   2.52
# Zimbabwe                           5.7840                   2.95
#
# [116 rows x 2 columns]

# %%
iso_code = tourist.index
scaler = MinMaxScaler()
tourist_scaled = scaler.fit_transform(tourist)
tourist_scaled = pd.DataFrame(tourist_scaled, 
                              columns = ["new_cases_smoothed_per_million", "tourist_service_index"], 
                              index = iso_code)
tourist_scaled
# Out:
#            new_cases_smoothed_per_million  tourist_service_index
# location
# Albania                          0.227473               0.458753
# Algeria                          0.013892               0.022133
# Argentina                        0.396325               0.563380
# Armenia                          0.312035               0.523139
# Australia                        0.002818               0.871227
# ...                                   ...                    ...
# Venezuela                        0.060524               0.247485
# Vietnam                          0.000296               0.225352
# Yemen                            0.000613               0.028169
# Zambia                           0.017378               0.158954
# Zimbabwe                         0.015163               0.245473
#
# [116 rows x 2 columns]

# %%
Nc = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(tourist_scaled).score(tourist_scaled) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()
#elbow at 2,3,4,5?

# %%
print(np.mean(tourist_scaled["new_cases_smoothed_per_million"]))
print(np.mean(tourist_scaled["tourist_service_index"]))
# Out:
# 0.2278300392655722
# 0.5257579962533823

# %%
model = KMeans(n_clusters = 5)
model.fit(tourist_scaled)
model.labels_
colormap = np.array(['Red', 'Blue', 'Green', "Purple", "Black"])

z = plt.scatter(tourist_scaled.new_cases_smoothed_per_million, tourist_scaled.tourist_service_index, c = colormap[model.labels_])
plt.xlabel("new_cases_smoothed_per_million")
plt.ylabel("tourist_service_index")
plt.show()

# %%
data_with_clusters = tourist_scaled.copy()
data_with_clusters['Clusters'] = model.labels_

# %%
data_with_clusters[data_with_clusters['Clusters'] == 0]
# Out:
#                     new_cases_smoothed_per_million  tourist_service_index  \
# location
# Australia                                 0.002818               0.871227
# Barbados                                  0.066386               0.551308
# Dominican Republic                        0.133034               0.621730
# Finland                                   0.120689               0.589537
# Hong Kong                                 0.002776               0.511066
# Iceland                                   0.093934               0.859155
# Jamaica                                   0.068769               0.637827
# Japan                                     0.025569               0.800805
# Mauritius                                 0.009999               0.651911
# Mexico                                    0.106574               0.619718
# Myanmar                                   0.015470               0.551308
# New Zealand                               0.002118               0.818913
# Norway                                    0.189185               0.688129
# Peru                                      0.238955               0.726358
# Qatar                                     0.203323               0.663984
# Saudi Arabia                              0.036442               0.684105
# Singapore                                 0.028019               0.682093
# South Africa                              0.108071               0.517103
# South Korea                               0.026374               0.768612
# Taiwan                                    0.000456               0.609658
# Thailand                                  0.008614               0.849095
# Uruguay                                   0.148399               0.621730
#
#                     Clusters
# location
# Australia                  0
# Barbados                   0
# Dominican Republic         0
# Finland                    0
# Hong Kong                  0
# Iceland                    0
# Jamaica                    0
# Japan                      0
# Mauritius                  0
# Mexico                     0
# Myanmar                    0
# New Zealand                0
# Norway                     0
# Peru                       0
# Qatar                      0
# Saudi Arabia               0
# Singapore                  0
# South Africa               0
# South Korea                0
# Taiwan                     0
# Thailand                   0
# Uruguay                    0

# %%
al = medians
al
# Out:
#            new_cases_smoothed_per_million  stringency_index  positive_rate  \
# location
# Albania                           86.7700             56.48         0.1670
# Algeria                            5.2990             69.44         0.0590
# Argentina                        151.1790             77.31         0.1830
# Armenia                          119.0265             57.41         0.1185
# Australia                          1.0750             65.28         0.0009
# ...                                   ...               ...            ...
# Venezuela                         23.0870             84.26         0.0590
# Vietnam                            0.1130             67.13         0.0719
# Yemen                              0.2340             27.78         0.0590
# Zambia                             6.6290             43.52         0.0395
# Zimbabwe                           5.7840             67.59         0.0514
#
#            cost_living_index  tourist_service_index
# location
# Albania                35.50                   4.01
# Algeria                26.87                   1.84
# Argentina              34.69                   4.53
# Armenia                33.89                   4.33
# Australia              77.75                   6.06
# ...                      ...                    ...
# Venezuela              43.20                   2.96
# Vietnam                37.48                   2.85
# Yemen                  53.14                   1.87
# Zambia                 33.04                   2.52
# Zimbabwe               45.68                   2.95
#
# [116 rows x 5 columns]

# %%
iso_code = al.index
scaler = MinMaxScaler()
al_scaled = scaler.fit_transform(al)
al_scaled = pd.DataFrame(al_scaled, 
                              columns = ["new_cases_smoothed_per_million", "stringency_index", 
                                         "positive_rate","cost_living_index", "tourist_service_index"], 
                              index = iso_code)
al_scaled

Nc = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]
kmeans
score = [kmeans[i].fit(al_scaled).score(al_scaled) for i in range(len(kmeans))]
score
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
model = KMeans(n_clusters = 7)
model.fit(al_scaled)
model.labels_
#colormap = np.array(['Red', 'Blue', 'Green', "Purple", "Black"])

#z = plt.scatter(al.new_cases_smoothed_per_million, tourist_scaled.tourist_service_index, c = colormap[model.labels_])
#plt.xlabel("new_cases_smoothed_per_million")
#plt.ylabel("tourist_service_index")
#plt.show()
# Out:
# array([4, 5, 4, 3, 1, 6, 5, 2, 5, 1, 6, 4, 3, 3, 6, 5, 0, 6, 3, 5, 4, 4,
#        6, 6, 1, 4, 4, 4, 0, 2, 0, 1, 6, 2, 6, 0, 6, 4, 5, 1, 3, 1, 5, 5,
#        5, 6, 6, 6, 3, 1, 3, 5, 5, 3, 2, 3, 2, 6, 3, 6, 1, 4, 4, 5, 2, 5,
#        3, 5, 2, 1, 0, 5, 3, 1, 3, 5, 3, 4, 3, 5, 3, 6, 3, 3, 3, 5, 1, 0,
#        2, 2, 1, 2, 2, 3, 1, 6, 5, 4, 1, 6, 1, 0, 1, 4, 3, 5, 4, 6, 6, 6,
#        3, 5, 5, 0, 0, 5], dtype=int32)

# %%
data_with_clusters = al_scaled.copy()
data_with_clusters['Clusters'] = model.labels_
data_with_clusters[data_with_clusters['Clusters'] == 6]
# Out:
#                       new_cases_smoothed_per_million  stringency_index  \
# location
# Austria                                     0.440768          0.682997
# Belgium                                     0.455179          0.561043
# Bulgaria                                    0.323157          0.524430
# Canada                                      0.189920          0.823127
# Croatia                                     0.363896          0.426841
# Cyprus                                      0.531249          0.548795
# France                                      0.519156          0.768339
# Germany                                     0.250423          0.780456
# Greece                                      0.416553          0.853615
# Ireland                                     0.288572          0.615830
# Israel                                      0.394039          0.634137
# Italy                                       0.249903          0.829316
# Luxembourg                                  0.520925          0.512182
# Malta                                       0.274297          0.585408
# Portugal                                    0.257165          0.707362
# Spain                                       0.412366          0.689056
# Switzerland                                 0.384801          0.548795
# United Arab Emirates                        0.259392          0.609772
# United Kingdom                              0.583566          0.713420
# United States                               0.490359          0.664691
#
#                       positive_rate  cost_living_index  tourist_service_index  \
# location
# Austria                    0.023768           0.494247               0.991952
# Belgium                    0.188406           0.509427               0.698189
# Bulgaria                   0.210580           0.178478               0.849095
# Canada                     0.108406           0.486319               0.875252
# Croatia                    0.335362           0.280576               0.955734
# Cyprus                     0.020290           0.378130               0.788732
# France                     0.150725           0.524123               0.796781
# Germany                    0.215942           0.441458               0.849095
# Greece                     0.084638           0.350962               0.808853
# Ireland                    0.141739           0.542686               0.816901
# Israel                     0.094203           0.658706               0.746479
# Italy                      0.097681           0.450063               0.861167
# Luxembourg                 0.060870           0.585710               0.845070
# Malta                      0.087246           0.463309               0.752515
# Portugal                   0.101739           0.270908               1.000000
# Spain                      0.244928           0.328338               0.971831
# Switzerland                0.192754           1.000000               0.899396
# United Arab Emirates       0.022029           0.371362               0.784708
# United Kingdom             0.105507           0.480808               0.879276
# United States              0.208696           0.485449               0.971831
#
#                       Clusters
# location
# Austria                      6
# Belgium                      6
# Bulgaria                     6
# Canada                       6
# Croatia                      6
# Cyprus                       6
# France                       6
# Germany                      6
# Greece                       6
# Ireland                      6
# Israel                       6
# Italy                        6
# Luxembourg                   6
# Malta                        6
# Portugal                     6
# Spain                        6
# Switzerland                  6
# United Arab Emirates         6
# United Kingdom               6
# United States                6
