# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("data/data.txt")
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#   iso_code location continent        date  new_cases_per_million  \
# 0      ALB  Albania    Europe  2020-02-25                    NaN
# 1      ALB  Albania    Europe  2020-02-26                    NaN
# 2      ALB  Albania    Europe  2020-02-27                    NaN
# 3      ALB  Albania    Europe  2020-02-28                    NaN
# 4      ALB  Albania    Europe  2020-02-29                    NaN
#
#    new_cases_smoothed_per_million  stringency_index  positive_rate  \
# 0                             NaN              8.33            NaN
# 1                             NaN              8.33            NaN
# 2                             NaN              8.33            NaN
# 3                             NaN              8.33            NaN
# 4                             NaN              8.33            NaN
#
#    human_development_index  cost_living_index  tourist_service_index  \
# 0                    0.795               35.5                   4.01
# 1                    0.795               35.5                   4.01
# 2                    0.795               35.5                   4.01
# 3                    0.795               35.5                   4.01
# 4                    0.795               35.5                   4.01
#
#    international_travel_controls
# 0                            1.0
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style  type="text/css" >
# #T_55ef1_row0_col0,#T_55ef1_row1_col1,#T_55ef1_row2_col2,#T_55ef1_row3_col3,#T_55ef1_row4_col4,#T_55ef1_row5_col5,#T_55ef1_row6_col6,#T_55ef1_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_55ef1_row0_col1{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_55ef1_row0_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_55ef1_row0_col3{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_55ef1_row0_col4,#T_55ef1_row0_col6,#T_55ef1_row5_col7,#T_55ef1_row6_col0,#T_55ef1_row6_col7{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_55ef1_row0_col5,#T_55ef1_row6_col1{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_55ef1_row0_col7,#T_55ef1_row2_col4,#T_55ef1_row2_col6{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_55ef1_row1_col0{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_55ef1_row1_col2{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_55ef1_row1_col3{
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }#T_55ef1_row1_col4{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_55ef1_row1_col5,#T_55ef1_row4_col1{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_55ef1_row1_col6,#T_55ef1_row7_col5{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_55ef1_row1_col7,#T_55ef1_row7_col3{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_55ef1_row2_col0,#T_55ef1_row2_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_55ef1_row2_col3{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_55ef1_row2_col5{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_55ef1_row2_col7,#T_55ef1_row7_col2{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_55ef1_row3_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_55ef1_row3_col1{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_55ef1_row3_col2{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_55ef1_row3_col4,#T_55ef1_row3_col5,#T_55ef1_row3_col6,#T_55ef1_row3_col7,#T_55ef1_row5_col2,#T_55ef1_row5_col3,#T_55ef1_row7_col0,#T_55ef1_row7_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_55ef1_row4_col0{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_55ef1_row4_col2{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_55ef1_row4_col3{
#             background-color:  #5977e3;
#             color:  #000000;
#         }#T_55ef1_row4_col5{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_55ef1_row4_col6{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_55ef1_row4_col7{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_55ef1_row5_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_55ef1_row5_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_55ef1_row5_col4{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_55ef1_row5_col6{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_55ef1_row6_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_55ef1_row6_col3{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_55ef1_row6_col4{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_55ef1_row6_col5{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_55ef1_row7_col4{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_55ef1_row7_col6{
#             background-color:  #799cf8;
#             color:  #000000;
#         }</style><table id="T_55ef1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases_per_million</th>        <th class="col_heading level0 col1" >new_cases_smoothed_per_million</th>        <th class="col_heading level0 col2" >stringency_index</th>        <th class="col_heading level0 col3" >positive_rate</th>        <th class="col_heading level0 col4" >human_development_index</th>        <th class="col_heading level0 col5" >cost_living_index</th>        <th class="col_heading level0 col6" >tourist_service_index</th>        <th class="col_heading level0 col7" >international_travel_controls</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_55ef1_level0_row0" class="row_heading level0 row0" >new_cases_per_million</th>
#                         <td id="T_55ef1_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_55ef1_row0_col1" class="data row0 col1" >0.861841</td>
#                         <td id="T_55ef1_row0_col2" class="data row0 col2" >-0.049752</td>
#                         <td id="T_55ef1_row0_col3" class="data row0 col3" >0.387745</td>
#                         <td id="T_55ef1_row0_col4" class="data row0 col4" >0.199990</td>
#                         <td id="T_55ef1_row0_col5" class="data row0 col5" >0.151923</td>
#                         <td id="T_55ef1_row0_col6" class="data row0 col6" >0.181845</td>
#                         <td id="T_55ef1_row0_col7" class="data row0 col7" >-0.063537</td>
#             </tr>
#             <tr>
#                         <th id="T_55ef1_level0_row1" class="row_heading level0 row1" >new_cases_smoothed_per_million</th>
#                         <td id="T_55ef1_row1_col0" class="data row1 col0" >0.861841</td>
#                         <td id="T_55ef1_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_55ef1_row1_col2" class="data row1 col2" >-0.062463</td>
#                         <td id="T_55ef1_row1_col3" class="data row1 col3" >0.439031</td>
#                         <td id="T_55ef1_row1_col4" class="data row1 col4" >0.230480</td>
#                         <td id="T_55ef1_row1_col5" class="data row1 col5" >0.174211</td>
#                         <td id="T_55ef1_row1_col6" class="data row1 col6" >0.209564</td>
#                         <td id="T_55ef1_row1_col7" class="data row1 col7" >-0.079141</td>
#             </tr>
#             <tr>
#                         <th id="T_55ef1_level0_row2" class="row_heading level0 row2" >stringency_index</th>
#                         <td id="T_55ef1_row2_col0" class="data row2 col0" >-0.049752</td>
#                         <td id="T_55ef1_row2_col1" class="data row2 col1" >-0.062463</td>
#                         <td id="T_55ef1_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_55ef1_row2_col3" class="data row2 col3" >0.069490</td>
#                         <td id="T_55ef1_row2_col4" class="data row2 col4" >0.005701</td>
#                         <td id="T_55ef1_row2_col5" class="data row2 col5" >-0.111798</td>
#                         <td id="T_55ef1_row2_col6" class="data row2 col6" >-0.014063</td>
#                         <td id="T_55ef1_row2_col7" class="data row2 col7" >0.488462</td>
#             </tr>
#             <tr>
#                         <th id="T_55ef1_level0_row3" class="row_heading level0 row3" >positive_rate</th>
#                         <td id="T_55ef1_row3_col0" class="data row3 col0" >0.387745</td>
#                         <td id="T_55ef1_row3_col1" class="data row3 col1" >0.439031</td>
#                         <td id="T_55ef1_row3_col2" class="data row3 col2" >0.069490</td>
#                         <td id="T_55ef1_row3_col3" class="data row3 col3" >1.000000</td>

# %%
df_new = df.drop(columns=['new_cases_smoothed_per_million', "human_development_index"])
df_new.head()
# Out:
#   iso_code location continent        date  new_cases_per_million  \
# 0      ALB  Albania    Europe  2020-02-25                    NaN
# 1      ALB  Albania    Europe  2020-02-26                    NaN
# 2      ALB  Albania    Europe  2020-02-27                    NaN
# 3      ALB  Albania    Europe  2020-02-28                    NaN
# 4      ALB  Albania    Europe  2020-02-29                    NaN
#
#    stringency_index  positive_rate  cost_living_index  tourist_service_index  \
# 0              8.33            NaN               35.5                   4.01
# 1              8.33            NaN               35.5                   4.01
# 2              8.33            NaN               35.5                   4.01
# 3              8.33            NaN               35.5                   4.01
# 4              8.33            NaN               35.5                   4.01
#
#    international_travel_controls
# 0                            1.0
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0

# %%
corr_new = df_new.corr()
corr_new.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_ae6ab_row0_col0,#T_ae6ab_row1_col1,#T_ae6ab_row2_col2,#T_ae6ab_row3_col3,#T_ae6ab_row4_col4,#T_ae6ab_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ae6ab_row0_col1{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_ae6ab_row0_col2{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_ae6ab_row0_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_ae6ab_row0_col4,#T_ae6ab_row3_col5,#T_ae6ab_row4_col0,#T_ae6ab_row4_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_ae6ab_row0_col5,#T_ae6ab_row1_col4{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_ae6ab_row1_col0{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_ae6ab_row1_col2{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_ae6ab_row1_col3{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_ae6ab_row1_col5,#T_ae6ab_row5_col1{
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }#T_ae6ab_row2_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_ae6ab_row2_col1{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_ae6ab_row2_col3,#T_ae6ab_row2_col4,#T_ae6ab_row2_col5,#T_ae6ab_row3_col1,#T_ae6ab_row3_col2,#T_ae6ab_row5_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_ae6ab_row3_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_ae6ab_row3_col4{
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }#T_ae6ab_row4_col1{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_ae6ab_row4_col2{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_ae6ab_row4_col3{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_ae6ab_row5_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_ae6ab_row5_col3{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_ae6ab_row5_col4{
#             background-color:  #799cf8;
#             color:  #000000;
#         }</style><table id="T_ae6ab_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >new_cases_per_million</th>        <th class="col_heading level0 col1" >stringency_index</th>        <th class="col_heading level0 col2" >positive_rate</th>        <th class="col_heading level0 col3" >cost_living_index</th>        <th class="col_heading level0 col4" >tourist_service_index</th>        <th class="col_heading level0 col5" >international_travel_controls</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae6ab_level0_row0" class="row_heading level0 row0" >new_cases_per_million</th>
#                         <td id="T_ae6ab_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ae6ab_row0_col1" class="data row0 col1" >-0.049752</td>
#                         <td id="T_ae6ab_row0_col2" class="data row0 col2" >0.387745</td>
#                         <td id="T_ae6ab_row0_col3" class="data row0 col3" >0.151923</td>
#                         <td id="T_ae6ab_row0_col4" class="data row0 col4" >0.181845</td>
#                         <td id="T_ae6ab_row0_col5" class="data row0 col5" >-0.063537</td>
#             </tr>
#             <tr>
#                         <th id="T_ae6ab_level0_row1" class="row_heading level0 row1" >stringency_index</th>
#                         <td id="T_ae6ab_row1_col0" class="data row1 col0" >-0.049752</td>
#                         <td id="T_ae6ab_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_ae6ab_row1_col2" class="data row1 col2" >0.069490</td>
#                         <td id="T_ae6ab_row1_col3" class="data row1 col3" >-0.111798</td>
#                         <td id="T_ae6ab_row1_col4" class="data row1 col4" >-0.014063</td>
#                         <td id="T_ae6ab_row1_col5" class="data row1 col5" >0.488462</td>
#             </tr>
#             <tr>
#                         <th id="T_ae6ab_level0_row2" class="row_heading level0 row2" >positive_rate</th>
#                         <td id="T_ae6ab_row2_col0" class="data row2 col0" >0.387745</td>
#                         <td id="T_ae6ab_row2_col1" class="data row2 col1" >0.069490</td>
#                         <td id="T_ae6ab_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_ae6ab_row2_col3" class="data row2 col3" >-0.156852</td>
#                         <td id="T_ae6ab_row2_col4" class="data row2 col4" >-0.067758</td>
#                         <td id="T_ae6ab_row2_col5" class="data row2 col5" >-0.117077</td>
#             </tr>
#             <tr>
#                         <th id="T_ae6ab_level0_row3" class="row_heading level0 row3" >cost_living_index</th>
#                         <td id="T_ae6ab_row3_col0" class="data row3 col0" >0.151923</td>
#                         <td id="T_ae6ab_row3_col1" class="data row3 col1" >-0.111798</td>
#                         <td id="T_ae6ab_row3_col2" class="data row3 col2" >-0.156852</td>
#                         <td id="T_ae6ab_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_ae6ab_row3_col4" class="data row3 col4" >0.617476</td>
#                         <td id="T_ae6ab_row3_col5" class="data row3 col5" >0.143156</td>
#             </tr>
#             <tr>
#                         <th id="T_ae6ab_level0_row4" class="row_heading level0 row4" >tourist_service_index</th>
#                         <td id="T_ae6ab_row4_col0" class="data row4 col0" >0.181845</td>
#                         <td id="T_ae6ab_row4_col1" class="data row4 col1" >-0.014063</td>
#                         <td id="T_ae6ab_row4_col2" class="data row4 col2" >-0.067758</td>
#                         <td id="T_ae6ab_row4_col3" class="data row4 col3" >0.617476</td>
#                         <td id="T_ae6ab_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_ae6ab_row4_col5" class="data row4 col5" >0.140614</td>
#             </tr>
#             <tr>
#                         <th id="T_ae6ab_level0_row5" class="row_heading level0 row5" >international_travel_controls</th>
#                         <td id="T_ae6ab_row5_col0" class="data row5 col0" >-0.063537</td>
#                         <td id="T_ae6ab_row5_col1" class="data row5 col1" >0.488462</td>
#                         <td id="T_ae6ab_row5_col2" class="data row5 col2" >-0.117077</td>
#                         <td id="T_ae6ab_row5_col3" class="data row5 col3" >0.143156</td>
#                         <td id="T_ae6ab_row5_col4" class="data row5 col4" >0.140614</td>
#                         <td id="T_ae6ab_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
x = df_new.iloc[:,4:] # 1t for rows and second for columns
x.head()
# Out:
#    new_cases_per_million  stringency_index  positive_rate  cost_living_index  \
# 0                    NaN              8.33            NaN               35.5
# 1                    NaN              8.33            NaN               35.5
# 2                    NaN              8.33            NaN               35.5
# 3                    NaN              8.33            NaN               35.5
# 4                    NaN              8.33            NaN               35.5
#
#    tourist_service_index  international_travel_controls
# 0                   4.01                            1.0
# 1                   4.01                            1.0
# 2                   4.01                            1.0
# 3                   4.01                            1.0
# 4                   4.01                            1.0

# %%
x.isna().sum()
# Out:
# new_cases_per_million              510
# stringency_index                  3422
# positive_rate                    24328
# cost_living_index                    0
# tourist_service_index             2213
# international_travel_controls     2493
# dtype: int64

# %%
column_means = x.mean()
x_new = x.fillna(column_means)
x_new.head()
# Out:
#    new_cases_per_million  stringency_index  positive_rate  cost_living_index  \
# 0             207.814059              8.33       0.101155               35.5
# 1             207.814059              8.33       0.101155               35.5
# 2             207.814059              8.33       0.101155               35.5
# 3             207.814059              8.33       0.101155               35.5
# 4             207.814059              8.33       0.101155               35.5
#
#    tourist_service_index  international_travel_controls
# 0                   4.01                            1.0
# 1                   4.01                            1.0
# 2                   4.01                            1.0
# 3                   4.01                            1.0
# 4                   4.01                            1.0

# %%
wcss=[]
for i in range(1,9):
    kmeans = KMeans(i)
    kmeans.fit(x_new)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

number_clusters = range(1,9)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans = KMeans(8)
kmeans.fit(x_new)
identified_clusters = kmeans.fit_predict(x_new)
identified_clusters
# Out:
# array([0, 0, 0, ..., 2, 2, 0], dtype=int32)

# %%
data_with_clusters = df_new.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['stringency_index'],data_with_clusters['cost_living_index'],c=data_with_clusters['Clusters'],cmap='rainbow')

# %%
df_new.head()
# Out:
#   iso_code location continent        date  new_cases_per_million  \
# 0      ALB  Albania    Europe  2020-02-25                    NaN
# 1      ALB  Albania    Europe  2020-02-26                    NaN
# 2      ALB  Albania    Europe  2020-02-27                    NaN
# 3      ALB  Albania    Europe  2020-02-28                    NaN
# 4      ALB  Albania    Europe  2020-02-29                    NaN
#
#    stringency_index  positive_rate  cost_living_index  tourist_service_index  \
# 0              8.33            NaN               35.5                   4.01
# 1              8.33            NaN               35.5                   4.01
# 2              8.33            NaN               35.5                   4.01
# 3              8.33            NaN               35.5                   4.01
# 4              8.33            NaN               35.5                   4.01
#
#    international_travel_controls
# 0                            1.0
# 1                            1.0
# 2                            1.0
# 3                            1.0
# 4                            1.0

# %%
df_new["date"] = pd.to_datetime(df_new["date"])

# %%
feb = (df_new['date'] >= '2022-02-01') & (df_new['date'] < '2022-03-01')
df_feb = df_new.loc[feb]
df_feb.head()
# Out:
#     iso_code location continent       date  new_cases_per_million  \
# 707      ALB  Albania    Europe 2022-02-01                  0.000
# 708      ALB  Albania    Europe 2022-02-02                938.762
# 709      ALB  Albania    Europe 2022-02-03                  0.000
# 710      ALB  Albania    Europe 2022-02-04                672.483
# 711      ALB  Albania    Europe 2022-02-05                  0.000
#
#      stringency_index  positive_rate  cost_living_index  \
# 707             61.11         0.6065               35.5
# 708             61.11         0.6046               35.5
# 709             61.11         0.5827               35.5
# 710             61.11         0.6246               35.5
# 711             61.11         0.6413               35.5
#
#      tourist_service_index  international_travel_controls
# 707                   4.01                            3.0
# 708                   4.01                            3.0
# 709                   4.01                            3.0
# 710                   4.01                            3.0
# 711                   4.01                            3.0

# %%
df_feb = df_feb.drop(columns=['iso_code', "continent", "date"])
df_feb.head()
# Out:
#     location  new_cases_per_million  stringency_index  positive_rate  \
# 707  Albania                  0.000             61.11         0.6065
# 708  Albania                938.762             61.11         0.6046
# 709  Albania                  0.000             61.11         0.5827
# 710  Albania                672.483             61.11         0.6246
# 711  Albania                  0.000             61.11         0.6413
#
#      cost_living_index  tourist_service_index  international_travel_controls
# 707               35.5                   4.01                            3.0
# 708               35.5                   4.01                            3.0
# 709               35.5                   4.01                            3.0
# 710               35.5                   4.01                            3.0
# 711               35.5                   4.01                            3.0

# %%
import plotly.express as px

# %%
feb_groupped = df_feb.groupby("location").agg({'new_cases_per_million':'sum','stringency_index':'mean','positive_rate':'mean',"cost_living_index":"mean", "tourist_service_index":"mean", "international_travel_controls":"mean"})
feb_groupped.head()
# Out:
#            new_cases_per_million  stringency_index  positive_rate  \
# location
# Albania                 4531.952         61.110000       0.519526
# Algeria                  287.317         59.653214            NaN
# Argentina              11445.908         35.190000       0.229107
# Armenia                17531.926               NaN       0.300214
# Australia              25484.702         53.177143       0.271000
#
#            cost_living_index  tourist_service_index  \
# location
# Albania                35.50                   4.01
# Algeria                26.87                   1.84
# Argentina              34.69                   4.53
# Armenia                33.89                   4.33
# Australia              77.75                   6.06
#
#            international_travel_controls
# location
# Albania                              3.0
# Algeria                              3.0
# Argentina                            2.0
# Armenia                              NaN
# Australia                            3.0

# %%
column_means = feb_groupped.mean()
feb_new = feb_groupped.fillna(column_means)
feb_new.head()
# Out:
#            new_cases_per_million  stringency_index  positive_rate  \
# location
# Albania                 4531.952         61.110000       0.519526
# Algeria                  287.317         59.653214       0.221399
# Argentina              11445.908         35.190000       0.229107
# Armenia                17531.926         46.990653       0.300214
# Australia              25484.702         53.177143       0.271000
#
#            cost_living_index  tourist_service_index  \
# location
# Albania                35.50                   4.01
# Algeria                26.87                   1.84
# Argentina              34.69                   4.53
# Armenia                33.89                   4.33
# Australia              77.75                   6.06
#
#            international_travel_controls
# location
# Albania                         3.000000
# Algeria                         3.000000
# Argentina                       2.000000
# Armenia                         2.083755
# Australia                       3.000000

# %%
wcss=[]
for i in range(1,9):
    kmeans = KMeans(i)
    kmeans.fit(feb_new)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

number_clusters = range(1,9)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans = KMeans(8)
kmeans.fit(feb_new)
identified_clusters = kmeans.fit_predict(feb_new)
identified_clusters
# Out:
# array([0, 0, 7, 7, 4, 1, 7, 1, 0, 4, 4, 0, 0, 7, 7, 0, 0, 0, 2, 0, 0, 7,
#        4, 1, 5, 0, 0, 0, 0, 6, 0, 4, 2, 6, 2, 0, 2, 0, 0, 4, 7, 5, 0, 0,
#        0, 7, 1, 4, 0, 7, 4, 0, 0, 7, 3, 7, 1, 4, 7, 0, 2, 0, 7, 7, 7, 0,
#        0, 0, 6, 7, 0, 0, 7, 1, 0, 0, 7, 0, 0, 0, 7, 2, 0, 4, 4, 0, 0, 0,
#        4, 7, 1, 6, 1, 0, 2, 7, 0, 0, 4, 1, 0, 0, 0, 0, 4, 0, 7, 0, 7, 7,
#        2, 0, 7, 0, 0, 0], dtype=int32)

# %%
data_with_clusters = feb_new.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['new_cases_per_million'],data_with_clusters['international_travel_controls'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.xlabel("new_cases_per_million")
plt.ylabel("international_travel_controls")
plt.show()

# %%
df_feb_map = pd.DataFrame(df_feb, columns=['iso_code', 'cost_living_index', 'service_index'])

kmeans = KMeans(n_clusters=3)

y = kmeans.fit_predict(df[['Feat_1', 'Feat_2', 'Feat_3', 'Feat_4']])

df['Cluster'] = y
